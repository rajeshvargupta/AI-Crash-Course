# %%
class human:
    def __init__(self,height,weight):
        self.height= height
        self.weight= weight

    def move(self):
        print("lets go")

# %%
ram = human(5.6,75)
ram.height
ram.weight
ram.move()
# Out:
# lets go

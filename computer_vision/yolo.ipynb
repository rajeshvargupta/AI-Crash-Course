# %% [markdown]
# ## Image Classification

# %%
from ultralytics import YOLO
model = YOLO("yolo11n-cls.pt")
results = model("1.jpeg",save=True)
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 224x224 restaurant 0.68, library 0.12, lab_coat 0.03, projector 0.03, barbershop 0.01, 21.5ms
# Speed: 109.1ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/classify/predict2

# %% [markdown]
# ## Object Detection

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
results = model("1.jpeg",save=True)
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 640x480 10 persons, 6 chairs, 1 tv, 101.6ms
# Speed: 2.4ms preprocess, 101.6ms inference, 19.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/detect/predict2

# %%
model = YOLO("yolo11n-seg.pt")
results = model("1.jpeg",save=True)
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 640x480 11 persons, 5 chairs, 1 dining table, 1 tv, 81.5ms
# Speed: 2.5ms preprocess, 81.5ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/segment/predict3

# %%
model = YOLO("yolo11n-pose.pt")
results = model("1.jpeg",save=True)
# Out:
# ...
#
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 640x480 8 persons, 72.0ms
# Speed: 2.1ms preprocess, 72.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/pose/predict

# %%
model = YOLO("yolo11l.pt")
results = model.track(source="4.mp4",save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /Users/mac/Desktop/AI-Crash-Course/computer_vision/4.mp4: 384x640 12 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 267.0ms
# video 1/1 (frame 2/750) /Users/mac/Desktop/AI-Crash-Course/computer_vision/4.mp4: 384x640 12 persons, 1 bottle, 2 cups, 1 chair, 1 laptop, 284.0ms
# ...

# %%
model = YOLO("yolo11n-obb.pt") 


results = model("1.jpeg",save=True)
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 1024x768 (no detections), 187.8ms
# Speed: 5.9ms preprocess, 187.8ms inference, 5.0ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/obb/predict3

# %%
model = YOLO("yolo11n-obb.pt") 

results = model("1.jpeg",save=True)  

for result in results:
    xywhr = result.obb.xywhr  # center-x, center-y, width, height, angle (radians)
    xyxyxyxy = result.obb.xyxyxyxy  # polygon format with 4-points
    names = [result.names[cls.item()] for cls in result.obb.cls.int()]  # class name of each box
    confs = result.obb.conf  # confidence score of each box
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 1024x768 (no detections), 199.5ms
# Speed: 4.8ms preprocess, 199.5ms inference, 0.3ms postprocess per image at shape (1, 3, 1024, 768)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/obb/predict2

# %%
model = YOLO("yolo11n-pose.pt")  # load an official model


results = model("1.jpeg",save=True)  # predict on an image


for result in results:
    xy = result.keypoints.xy  # x and y coordinates
    xyn = result.keypoints.xyn  # normalized
    kpts = result.keypoints.data  # x, y, visibility (if available)
# Out:
# image 1/1 /Users/mac/Desktop/AI-Crash-Course/computer_vision/1.jpeg: 640x480 8 persons, 63.3ms
# Speed: 2.3ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /Users/mac/Desktop/AI-Crash-Course/computer_vision/runs/pose/predict3
